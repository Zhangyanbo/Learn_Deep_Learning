# %%
import torch

# %% [markdown]
# ## 定义网络

# %%
import torch.nn as nn
import torch.nn.functional as F

class FCN_bike(nn.Module):
    def __init__(self):
        super(FCN_bike, self).__init__()
        
        self.fcn1 = nn.Linear(42, 10)
        self.fcn2 = nn.Linear(10, 5)
        self.fcn3 = nn.Linear(5, 1)
    
    def forward(self, x):
        x = F.relu(self.fcn1(x))
        x = F.relu(self.fcn2(x))
        x = self.fcn3(x)
        
        return x
    
net = FCN_bike()
if torch.cuda.is_available():
    net = net.cuda()

# %% [markdown]
# ## 导入数据

# %%
import pandas as pd

# 读取数据集
dataPath = './bike predictor/bike-sharing-dataset/day.csv'
dataset = pd.read_csv(dataPath, index_col='instant', parse_dates=['dteday']) 
# index_col='instant', 设定instant为序号
# parse_dates=['dteday'], 将dteday列当作日期处理

dataset[1:10]

'''
目标

输入数据：holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed
预测：cnt
'''
# Out:
#             dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 2       2011-01-02       1   0     1        0        0           0
# 3       2011-01-03       1   0     1        0        1           1
# 4       2011-01-04       1   0     1        0        2           1
# 5       2011-01-05       1   0     1        0        3           1
# 6       2011-01-06       1   0     1        0        4           1
# 7       2011-01-07       1   0     1        0        5           1
# 8       2011-01-08       1   0     1        0        6           0
# 9       2011-01-09       1   0     1        0        0           0
# 10      2011-01-10       1   0     1        0        1           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# 2                 2  0.363478  0.353739  0.696087   0.248539     131
# 3                 1  0.196364  0.189405  0.437273   0.248309     120
# 4                 1  0.200000  0.212122  0.590435   0.160296     108
# 5                 1  0.226957  0.229270  0.436957   0.186900      82
# 6                 1  0.204348  0.233209  0.518261   0.089565      88
# 7                 2  0.196522  0.208839  0.498696   0.168726     148
# 8                 2  0.165000  0.162254  0.535833   0.266804      68
# 9                 1  0.138333  0.116175  0.434167   0.361950      54
# 10                1  0.150833  0.150888  0.482917   0.223267      41
#
#          registered   cnt
# instant
# 2               670   801
# 3              1229  1349
# 4              1454  1562
# 5              1518  1600
# 6              1518  1606
# 7              1362  1510
# 8               891   959
# 9               768   822
# 10             1280  1321

# %% [markdown]
# ## net可以同时接受多组输入

# %%
x = torch.randn(5, 42)
if torch.cuda.is_available():
    x = x.cuda()
print(x)
# Out:
# tensor([[ 0.5152, -1.6969,  0.6745, -0.3874, -0.5669, -1.2125, -1.6065, -0.3563,
#           1.4927, -1.1233,  1.0992,  0.2423,  0.4670, -0.3917, -1.0954, -0.7122,
#           0.4856,  0.5065,  0.6590, -1.3355, -0.1759, -0.2004,  0.1712,  0.4703,
#           0.3621,  0.4460, -0.9291,  0.0669,  0.8880,  0.1099, -1.0426, -1.0404,
#           0.4872, -1.5752,  0.0730,  2.1223, -0.5021, -1.9540,  0.0466,  1.0521,
#          -0.2304, -0.4659],
#         [ 0.2233,  0.1939, -0.1125, -0.2593,  0.9981,  0.0978,  0.0524, -0.1867,
#           2.7944,  0.4483,  1.1048,  1.5052,  0.0345, -0.6353,  0.7229,  0.1057,
#           0.6159,  0.2967,  2.2113, -0.5133, -1.7575, -1.1654,  1.1885, -1.0886,
#           0.3515,  1.1923, -0.7119,  0.8373, -1.3577, -0.3541,  1.2617,  0.6426,
#          -0.7269, -0.8418, -0.2972, -1.2410,  0.9395,  0.6444,  0.2652,  0.3186,
#           2.3140,  1.0285],
#         [ 0.6991, -0.3871, -0.2014, -0.2979,  0.5312,  1.5162,  0.9674,  0.1136,
#           0.3405, -0.0167, -1.4722, -0.3771,  1.1013, -0.7135,  0.9161, -0.1759,
#           1.2406,  0.4829,  0.6772,  0.2925,  0.8021,  0.2874,  1.3642, -1.7541,
#           0.2570, -1.1028,  0.0238, -1.1901, -0.0547,  0.6693,  0.1734,  0.5401,
#          -0.8723, -0.1546, -2.0179,  0.2099,  0.2373,  0.0965,  0.5692,  0.9516,
#          -0.7950,  0.6058],
#         [-1.1417, -0.9881,  0.6935,  1.0526,  1.2087, -0.0105,  1.7143,  0.6326,
#           0.2245,  1.4532,  0.9938, -1.0519, -0.2443,  1.6490,  0.3271,  1.1999,
#           0.1774, -0.0413, -0.7008,  0.7665,  0.8287,  0.3938, -0.4068,  0.8309,
#           1.6132, -0.3847, -0.9015,  1.4044, -2.3539, -0.1083,  1.4204,  0.4477,
#           0.6910, -0.8257, -0.9393,  0.8368, -0.9546, -0.2287,  0.9669, -0.0732,
#           0.6703, -0.8808],
#         [ 1.2779,  1.4770,  2.4192,  0.5377, -1.9548,  1.0868, -1.0139, -0.3758,
#          -2.3281, -0.5626,  0.5620, -0.8815, -1.0911, -1.1638, -0.6018, -2.4960,
#           0.7040, -0.2970,  1.1671,  0.3871,  1.3773,  0.7450, -2.8645,  0.7740,
#          -0.1309,  0.1611,  0.8187, -0.8027,  0.0905, -0.9534, -0.2746,  0.4417,
#          -0.3732,  1.3263,  1.3732,  0.2715, -1.3216,  1.1058,  0.6978,  0.1401,
#           1.5157, -0.5952]])

# %%
output = net.forward(x)
print(output)
# Out:
# tensor([[-0.0149],
#         [ 0.0136],
#         [ 0.0253],
#         [-0.0161],
#         [ 0.0153]], grad_fn=<ThAddmmBackward>)
