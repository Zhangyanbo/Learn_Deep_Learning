# %%
import torch

# %% [markdown]
# ## 定义网络

# %%
import torch.nn as nn
import torch.nn.functional as F

class FCN_bike(nn.Module):
    def __init__(self):
        super(FCN_bike, self).__init__()
        
        self.fcn1 = nn.Linear(42, 10)
        self.fcn2 = nn.Linear(10, 5)
        self.fcn3 = nn.Linear(5, 1)
    
    def forward(self, x):
        x = F.relu(self.fcn1(x))
        x = F.relu(self.fcn2(x))
        x = self.fcn3(x)
        
        return x
    
net = FCN_bike()
if torch.cuda.is_available():
    net = net.cuda()

# %% [markdown]
# ## 导入数据

# %%
import pandas as pd
import os.path

# 读取数据集
dataPath = './bike predictor/bike-sharing-dataset/day.csv'
dataset = pd.read_csv(dataPath, index_col='instant', parse_dates=['dteday']) 
# index_col='instant', 设定instant为序号
# parse_dates=['dteday'], 将dteday列当作日期处理

dataset[1:10]


#目标

#输入数据：holiday, weekday, workingday, weathersit, temp, atemp, hum, windspeed
#预测：cnt
# Out:
#             dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 2       2011-01-02       1   0     1        0        0           0
# 3       2011-01-03       1   0     1        0        1           1
# 4       2011-01-04       1   0     1        0        2           1
# 5       2011-01-05       1   0     1        0        3           1
# 6       2011-01-06       1   0     1        0        4           1
# 7       2011-01-07       1   0     1        0        5           1
# 8       2011-01-08       1   0     1        0        6           0
# 9       2011-01-09       1   0     1        0        0           0
# 10      2011-01-10       1   0     1        0        1           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# 2                 2  0.363478  0.353739  0.696087   0.248539     131
# 3                 1  0.196364  0.189405  0.437273   0.248309     120
# ...

# %% [markdown]
# ## net可以同时接受多组输入

# %%
x = torch.randn(5, 42)
if torch.cuda.is_available():
    x = x.cuda()
print(x)
# Out:
# tensor([[ 1.8075, -0.1171,  0.4681,  0.4683, -0.9106, -0.0333,  1.0402,  0.0256,
#           1.7428,  1.2912,  0.6036, -0.6896, -0.6793, -0.7155,  2.0052,  0.4920,
#           0.1947, -0.7871, -1.1980, -0.7829, -0.0855, -1.0689,  0.5615,  1.0345,
#          -1.1225, -0.6341,  1.1017,  0.4059,  0.3378,  0.7027,  1.2147, -0.4134,
#          -0.7292,  0.2532,  1.1688, -0.3468,  0.9663, -0.6671,  0.9237, -0.7565,
#          -0.9390,  0.9335],
#         [-0.3754,  1.1301, -0.5967,  0.4560,  0.7137, -0.5224, -1.1160,  0.8227,
#           0.5816,  0.6785,  0.3293, -0.2799, -0.0934,  0.1943,  1.1645,  0.2287,
#          -1.8747, -1.1312,  0.4234,  0.9909,  1.8854,  0.2861,  0.7666,  0.2528,
#           1.1926,  0.2244,  0.8881,  0.8402, -0.2325, -0.0585,  0.8648, -1.3586,
#          -0.6642,  0.3163,  0.1644, -0.7396, -2.2088, -1.5463,  0.4496, -1.4237,
#           0.3552, -0.2984],
#         [-1.0634, -0.6186,  0.9195,  0.1722,  0.8685, -0.1588, -0.3128,  0.7255,
# ...

# %%
output = net.forward(x)
print(output)
# Out:
# tensor([[-0.4183],
#         [-0.3489],
#         [-0.3577],
#         [-0.3940],
#         [-0.3283]], device='cuda:0', grad_fn=<AddmmBackward>)
